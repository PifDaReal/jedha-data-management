# %%
import pandas as pd
import requests
import boto3

# %%
#Top 35 cities in France
cities = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
# nominatim api
api_main = "https://nominatim.openstreetmap.org"
api_param = "/search?city="

#Remplacement des espaces en "+" dans le nom des villes pour éviter les erreurs lors du passage d'argument dans l'api
cities_url_format = []

for i in range(len(cities)):
    transform_city_name = cities[i].replace(" ", "+")
    cities_url_format.append(transform_city_name)
# gps coordinates of all the cities,
# &country=France&format=json&limit=1 ces parametres permettent d'affiner la recherche sur la France,
# on limite à 1 seul resultat retourné,
# on retourne le resultat au format json
cities_datas_json = []
for i in range(len(cities)):
    r = requests.get(api_main+api_param+cities_url_format[i]+"&country=France&format=json&limit=1")
    reponse = r.json()
    cities_datas_json.append(reponse)

cities_datas_json
# Out:
# [[{'place_id': 245061662,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 211285890,
#    'lat': '48.6359541',
#    'lon': '-1.511459954959514',
#    'class': 'place',
#    'type': 'islet',
#    'place_rank': 20,
#    'importance': 0.45543655678157396,
#    'addresstype': 'islet',
#    'name': 'Mont Saint-Michel',
#    'display_name': 'Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France',
#    'boundingbox': ['48.6349172', '48.6370310', '-1.5133292', '-1.5094796']}],
#  [{'place_id': 245319607,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 905534,
#    'lat': '48.649518',
#    'lon': '-2.0260409',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5764672172428952,
#    'addresstype': 'town',
#    'name': 'Saint-Malo',
#    'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35400, France',
#    'boundingbox': ['48.5979853', '48.6949736', '-2.0765246', '-1.9367259']}],
#  [{'place_id': 244577445,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 145776,
#    'lat': '49.2764624',
#    'lon': '-0.7024738',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5727003853621927,
#    'addresstype': 'town',
#    'name': 'Bayeux',
#    'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, 14400, France',
#    'boundingbox': ['49.2608124', '49.2934736', '-0.7275671', '-0.6757378']}],
#  [{'place_id': 84845221,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 104492,
#    'lat': '49.4938975',
#    'lon': '0.1079732',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6223325741883644,
#    'addresstype': 'city',
#    'name': 'Le Havre',
#    'display_name': 'Le Havre, Seine-Maritime, Normandie, France métropolitaine, France',
#    'boundingbox': ['49.4516697', '49.5401463', '0.0667992', '0.1955556']}],
#  [{'place_id': 84723446,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 75628,
#    'lat': '49.4404591',
#    'lon': '1.0939658',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6400726280583954,
#    'addresstype': 'city',
#    'name': 'Rouen',
#    'display_name': 'Rouen, Seine-Maritime, Normandie, France métropolitaine, France',
#    'boundingbox': ['49.4172001', '49.4652601', '1.0300648', '1.1521157']}],
#  [{'place_id': 83293737,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 71525,
#    'lat': '48.8534951',
#    'lon': '2.3483915',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 12,
#    'importance': 0.8317101715588673,
#    'addresstype': 'city',
#    'name': 'Paris',
#    'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#    'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']}],
#  [{'place_id': 84475595,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 114347,
#    'lat': '49.8941708',
#    'lon': '2.2956951',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6249489622249039,
#    'addresstype': 'city',
#    'name': 'Amiens',
#    'display_name': 'Amiens, Somme, Hauts-de-France, France métropolitaine, France',
#    'boundingbox': ['49.8468370', '49.9505487', '2.2235574', '2.3457767']}],
#  [{'place_id': 87056687,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 58404,
#    'lat': '50.6365654',
#    'lon': '3.0635282',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6532037863087654,
#    'addresstype': 'city',
#    'name': 'Lille',
#    'display_name': 'Lille, Nord, Hauts-de-France, France métropolitaine, France',
#    'boundingbox': ['50.6008264', '50.6612596', '2.9679677', '3.1257250']}],
#  [{'place_id': 104633806,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 71033,
#    'lat': '48.584614',
#    'lon': '7.7507127',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.674805427911873,
#    'addresstype': 'city',
#    'name': 'Strasbourg',
#    'display_name': 'Strasbourg, Bas-Rhin, Grand Est, France métropolitaine, France',
#    'boundingbox': ['48.4918610', '48.6461896', '7.6881371', '7.8360646']}],
#  [{'place_id': 104591830,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 4245068168,
#    'lat': '48.2495226',
#    'lon': '7.3454923',
#    'class': 'place',
#    'type': 'isolated_dwelling',
#    'place_rank': 22,
#    'importance': 0.2000099999999999,
#    'addresstype': 'isolated_dwelling',
#    'name': 'Château du Haut-Kœnigsbourg',
#    'display_name': 'Château du Haut-Kœnigsbourg, Orschwiller, Sélestat-Erstein, Bas-Rhin, Grand Est, France métropolitaine, 67600, France',
#    'boundingbox': ['48.2494726', '48.2495726', '7.3454423', '7.3455423']}],
#  [{'place_id': 104915802,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 61423,
#    'lat': '48.0777517',
#    'lon': '7.3579641',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5852964807109542,
#    'addresstype': 'town',
#    'name': 'Colmar',
#    'display_name': 'Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68000, France',
#    'boundingbox': ['48.0407053', '48.1820620', '7.3154803', '7.4691670']}],
#  [{'place_id': 104719705,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 79442,
#    'lat': '48.0447968',
#    'lon': '7.3079618',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5249720206561967,
#    'addresstype': 'village',
#    'name': 'Eguisheim',
#    'display_name': 'Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68420, France',
#    'boundingbox': ['48.0240327', '48.0515072', '7.2412792', '7.3518540']}],
#  [{'place_id': 78684513,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 103599,
#    'lat': '47.2380222',
#    'lon': '6.0243622',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6183511874833898,
#    'addresstype': 'city',
#    'name': 'Besançon',
#    'display_name': 'Besançon, Doubs, Bourgogne-Franche-Comté, France métropolitaine, 25000, France',
#    'boundingbox': ['47.2006872', '47.3200746', '5.9409668', '6.0835059']}],
#  [{'place_id': 80102208,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 74090,
#    'lat': '47.3215806',
#    'lon': '5.0414701',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6336193867801005,
#    'addresstype': 'city',
#    'name': 'Dijon',
#    'display_name': "Dijon, Côte-d'Or, Bourgogne-Franche-Comté, France métropolitaine, 21000, France",
#    'boundingbox': ['47.2862467', '47.3774741', '4.9624434', '5.1020598']}],
#  [{'place_id': 75756063,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 6791758,
#    'lat': '45.8992348',
#    'lon': '6.1288847',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5790769115704565,
#    'addresstype': 'city',
#    'name': 'Annecy',
#    'display_name': 'Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, France métropolitaine, France',
#    'boundingbox': ['45.8280024', '45.9766928', '6.0484121', '6.2043932']}],
#  [{'place_id': 75962893,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 80348,
#    'lat': '45.1875602',
#    'lon': '5.7357819',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.641808549572345,
#    'addresstype': 'city',
#    'name': 'Grenoble',
#    'display_name': 'Grenoble, Isère, Auvergne-Rhône-Alpes, France métropolitaine, France',
#    'boundingbox': ['45.1541442', '45.2140762', '5.6776059', '5.7531315']}],
#  [{'place_id': 79325170,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 120965,
#    'lat': '45.7578137',
#    'lon': '4.8320114',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6913775965432666,
#    'addresstype': 'city',
#    'name': 'Lyon',
#    'display_name': 'Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France',
#    'boundingbox': ['45.7073666', '45.8082628', '4.7718134', '4.8983774']}],
#  [{'place_id': 70154125,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'node',
#    'osm_id': 7193513219,
#    'lat': '43.7496562',
#    'lon': '6.3285616',
#    'class': 'natural',
#    'type': 'gorge',
#    'place_rank': 22,
#    'importance': 0.37814958574294283,
#    'addresstype': 'gorge',
#    'name': 'Gorges du Verdon',
#    'display_name': "Gorges du Verdon, La Palud-sur-Verdon, Castellane, Alpes-de-Haute-Provence, Provence-Alpes-Côte d'Azur, France métropolitaine, 04120, France",
#    'boundingbox': ['43.7496062', '43.7497062', '6.3285116', '6.3286116']}],
#  [{'place_id': 70195412,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 1118915,
#    'lat': '43.1506968',
#    'lon': '6.3419285',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.4773164194582208,
#    'addresstype': 'village',
#    'name': 'Bormes-les-Mimosas',
#    'display_name': "Bormes-les-Mimosas, Toulon, Var, Provence-Alpes-Côte d'Azur, France métropolitaine, 83230, France",
#    'boundingbox': ['43.0864271', '43.2278201', '6.2716142', '6.4514893']}],
#  [{'place_id': 70883649,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 76425,
#    'lat': '43.2140359',
#    'lon': '5.5396318',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.4767802490530644,
#    'addresstype': 'village',
#    'name': 'Cassis',
#    'display_name': "Cassis, Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13260, France",
#    'boundingbox': ['43.1884732', '43.2487231', '5.5063193', '5.5945199']}],
#  [{'place_id': 70805526,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 76469,
#    'lat': '43.2961743',
#    'lon': '5.3699525',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6813768937556641,
#    'addresstype': 'city',
#    'name': 'Marseille',
#    'display_name': "Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13000, France",
#    'boundingbox': ['43.1696228', '43.3910329', '5.2286312', '5.5324758']}],
#  [{'place_id': 70350081,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 70279,
#    'lat': '43.5298424',
#    'lon': '5.4474738',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.591084766383758,
#    'addresstype': 'city',
#    'name': 'Aix-en-Provence',
#    'display_name': "Aix-en-Provence, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, France",
#    'boundingbox': ['43.4461058', '43.6259224', '5.2694745', '5.5063013']}],
#  [{'place_id': 70472090,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 102478,
#    'lat': '43.9492493',
#    'lon': '4.8059012',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6220935210501682,
#    'addresstype': 'city',
#    'name': 'Avignon',
#    'display_name': "Avignon, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, France",
#    'boundingbox': ['43.8873819', '43.9967419', '4.7396309', '4.9271468']}],
#  [{'place_id': 74412901,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 380050,
#    'lat': '44.0121279',
#    'lon': '4.4196718',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5375332788749554,
#    'addresstype': 'village',
#    'name': 'Uzès',
#    'display_name': 'Uzès, Nîmes, Gard, Occitanie, France métropolitaine, 30700, France',
#    'boundingbox': ['43.9811093', '44.0765914', '4.3852299', '4.4467859']}],
#  [{'place_id': 70627983,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 378685,
#    'lat': '43.8374249',
#    'lon': '4.3600687',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6030547856893241,
#    'addresstype': 'city',
#    'name': 'Nîmes',
#    'display_name': 'Nîmes, Gard, Occitanie, France métropolitaine, France',
#    'boundingbox': ['43.7412659', '43.9230177', '4.2356708', '4.4496605']}],
#  [{'place_id': 70766008,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 272287,
#    'lat': '43.5661521',
#    'lon': '4.19154',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5323802893018253,
#    'addresstype': 'town',
#    'name': 'Aigues-Mortes',
#    'display_name': 'Aigues-Mortes, Nîmes, Gard, Occitanie, France métropolitaine, 30220, France',
#    'boundingbox': ['43.4958113', '43.5920372', '4.0760703', '4.2442867']}],
#  [{'place_id': 70745512,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 414459,
#    'lat': '43.4515922',
#    'lon': '4.4277202',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.4725165122764473,
#    'addresstype': 'town',
#    'name': 'Saintes-Maries-de-la-Mer',
#    'display_name': "Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13460, France",
#    'boundingbox': ['43.4062445', '43.5858463', '4.2301364', '4.6444785']}],
#  [{'place_id': 72068913,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 18409,
#    'lat': '42.52505',
#    'lon': '3.0831554',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5084088842062249,
#    'addresstype': 'village',
#    'name': 'Collioure',
#    'display_name': 'Collioure, Céret, Pyrénées-Orientales, Occitanie, France métropolitaine, 66190, France',
#    'boundingbox': ['42.4832453', '42.5341084', '3.0495074', '3.0994238']}],
#  [{'place_id': 72295757,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 37774,
#    'lat': '43.2130358',
#    'lon': '2.3491069',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5891672924570599,
#    'addresstype': 'town',
#    'name': 'Carcassonne',
#    'display_name': 'Carcassonne, Aude, Occitanie, France métropolitaine, 11000, France',
#    'boundingbox': ['43.1713069', '43.2443707', '2.2615684', '2.4362676']}],
#  [{'place_id': 71928040,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'way',
#    'osm_id': 127723368,
#    'lat': '42.9927428',
#    'lon': '1.6124975',
#    'class': 'waterway',
#    'type': 'river',
#    'place_rank': 19,
#    'importance': 0.27501,
#    'addresstype': 'river',
#    'name': 'Ariège',
#    'display_name': 'Ariège, La Coudounmine, Vernajoul, Foix, Ariège, Occitanie, France métropolitaine, 09000, France',
#    'boundingbox': ['42.9888173', '42.9951993', '1.6111888', '1.6138685']}],
#  [{'place_id': 73010739,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 35738,
#    'lat': '43.6044622',
#    'lon': '1.4442469',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6682142268493704,
#    'addresstype': 'city',
#    'name': 'Toulouse',
#    'display_name': 'Toulouse, Haute-Garonne, Occitanie, France métropolitaine, France',
#    'boundingbox': ['43.5326540', '43.6687080', '1.3503956', '1.5153795']}],
#  [{'place_id': 73471474,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 137735,
#    'lat': '44.0175835',
#    'lon': '1.3549991',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5542482145338697,
#    'addresstype': 'town',
#    'name': 'Montauban',
#    'display_name': 'Montauban, Tarn-et-Garonne, Occitanie, France métropolitaine, 82000, France',
#    'boundingbox': ['43.9512579', '44.0922122', '1.2865419', '1.4427914']}],
#  [{'place_id': 250442744,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 166717,
#    'lat': '43.4832523',
#    'lon': '-1.5592776',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.5796122503321824,
#    'addresstype': 'town',
#    'name': 'Biarritz',
#    'display_name': 'Biarritz, Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64200, France',
#    'boundingbox': ['43.4475698', '43.4945381', '-1.5773906', '-1.5343915']}],
#  [{'place_id': 250414078,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 166713,
#    'lat': '43.4945144',
#    'lon': '-1.4736657',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6027800210035323,
#    'addresstype': 'town',
#    'name': 'Bayonne',
#    'display_name': 'Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64100, France',
#    'boundingbox': ['43.4498733', '43.5188846', '-1.5048438', '-1.4172610']}],
#  [{'place_id': 249415241,
#    'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#    'osm_type': 'relation',
#    'osm_id': 117858,
#    'lat': '46.1591126',
#    'lon': '-1.1520434',
#    'class': 'boundary',
#    'type': 'administrative',
#    'place_rank': 16,
#    'importance': 0.6014837096874571,
#    'addresstype': 'city',
#    'name': 'La Rochelle',
#    'display_name': 'La Rochelle, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17000, France',
#    'boundingbox': ['46.1331804', '46.1908971', '-1.2419231', '-1.1110970']}]]

# %%
cities_list_tuple = []

for city in cities_datas_json:
    for city_datas in city:
        list_datas = [city_datas['place_id'], city_datas['display_name'], city_datas['lat'], city_datas['lon']]
        cities_list_tuple.append(tuple(list_datas))
wheather_df = pd.DataFrame(cities_list_tuple, columns=['place_id', 'city', 'lat', 'lon'])
wheather_df.head()
# Out:
#     place_id                                               city         lat  \
# 0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...  48.6359541
# 1  245319607  Saint-Malo, Ille-et-Vilaine, Bretagne, France ...   48.649518
# 2  244577445  Bayeux, Calvados, Normandie, France métropolit...  49.2764624
# 3   84845221  Le Havre, Seine-Maritime, Normandie, France mé...  49.4938975
# 4   84723446  Rouen, Seine-Maritime, Normandie, France métro...  49.4404591
#
#                   lon
# 0  -1.511459954959514
# 1          -2.0260409
# 2          -0.7024738
# 3           0.1079732
# 4           1.0939658

# %%
# WeatherMap class
class WeatherMap:
    def __init__(self):
        self.data = None
        self.date = None
        self.temp = None
        self.temp_min = None
        self.temp_max = None
        self.temp_day = None
        self.summary = None
        self.feels_like = None
        self.feels_like_day = None
        self.feels_like_night = None
        self.humidity = None
        self.wind_speed = None
        self.pop = None
        self.rain_volume = None
        
    def extract_date(self, daily_data):
        try:
            self.date = [day['dt'] for day in daily_data]
            return self.date
        except (KeyError, TypeError):
            return None

    def extract_summary(self, daily_data):
        try:
            self.summary = [day['summary'] for day in daily_data]
            return self.summary
        except (KeyError, TypeError):
            return None
        
    def extract_temp(self, daily_data):
        try:
            self.temp = [day['temp'] for day in daily_data]
            return self.temp
        except (KeyError, TypeError):
            return None

    def extract_temp_min(self, daily_data):
        try:
            self.temp_min = [day['temp']['min'] for day in daily_data]
            return self.temp_min
        except (KeyError, TypeError):
            return None
        
    def extract_temp_max(self, daily_data):
        try:
            self.temp_max = [day['temp']['max'] for day in daily_data]
            return self.temp_max
        except (KeyError, TypeError):
            return None

    def extract_temp_day(self, daily_data):
        try:
            self.temp_day = [day['temp']['day'] for day in daily_data]
            return self.temp_day
        except (KeyError, TypeError):
            return None
        
    def extract_feels_like(self, daily_data):
        try:
            self.feels_like = [day['feels_like'] for day in daily_data]
            return self.feels_like
        except (KeyError, TypeError):
            return None
        
    def extract_feels_like_day(self, daily_data):
        try:
            self.feels_like_day = [day['feels_like']['day'] for day in daily_data]
            return self.feels_like_day
        except (KeyError, TypeError):
            return None
        
    def extract_feels_like_night(self, daily_data):
        try:
            self.feels_like_night = [day['feels_like']['night'] for day in daily_data]
            return self.feels_like_night
        except (KeyError, TypeError):
            return None
        
    def extract_humidity(self, daily_data):
        try:
            self.humidity = [day['humidity'] for day in daily_data]
            return self.humidity
        except (KeyError, TypeError):
            return None

    def extract_wind_speed(self, daily_data):
        try:
            self.wind_speed = [day['wind_speed'] for day in daily_data]
            return self.wind_speed
        except (KeyError, TypeError):
            return None

    def extract_pop(self, daily_data):
        try:
            self.pop = [day['pop'] for day in daily_data]
            return self.pop
        except (KeyError, TypeError):
            return None
        
    def extract_rain_volume(self, daily_data):
        try:
            self.rain_volume = [day['rain'] if 'rain' in day else 0 for day in daily_data]
            return self.rain_volume
        except (KeyError, TypeError):
            return None

    def get_weather_data(self, lat, lon, API_KEY):
        base_url = "https://api.openweathermap.org/data/3.0/onecall?"
        params = {
            "lat": lat,
            "lon": lon,
            "appid": API_KEY, 
            "units": "metric",
            "exclude": "current,minutely,hourly,alerts"
        }

        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            self.data = data
            return self.data
        else:
            return None

# %%
# API_KEY_WEATHER
API_KEY_WEATHER = '4c048dfe144f662ab2884d19164c3363'

# new WeatherMap object
wm = WeatherMap()
wheather_df['weather_data'] = wheather_df.apply(lambda row: wm.get_weather_data(row['lat'], row['lon'], API_KEY_WEATHER), axis=1)  # type: ignore

# %%
wheather_df.head()
# Out:
#     place_id                                               city         lat  \
# 0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...  48.6359541
# 1  245319607  Saint-Malo, Ille-et-Vilaine, Bretagne, France ...   48.649518
# 2  244577445  Bayeux, Calvados, Normandie, France métropolit...  49.2764624
# 3   84845221  Le Havre, Seine-Maritime, Normandie, France mé...  49.4938975
# 4   84723446  Rouen, Seine-Maritime, Normandie, France métro...  49.4404591
#
#                   lon                                       weather_data
# 0  -1.511459954959514  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 1          -2.0260409  {'lat': 48.6495, 'lon': -2.026, 'timezone': 'E...
# 2          -0.7024738  {'lat': 49.2765, 'lon': -0.7025, 'timezone': '...
# 3           0.1079732  {'lat': 49.4939, 'lon': 0.108, 'timezone': 'Eu...
# 4           1.0939658  {'lat': 49.4405, 'lon': 1.094, 'timezone': 'Eu...

# %%
wheather_df['date'] = wheather_df['weather_data'].apply(lambda x: wm.extract_date(x['daily']) if 'daily' in x else None)
wheather_df['temp'] = wheather_df['weather_data'].apply(lambda x: wm.extract_temp(x['daily']) if 'daily' in x else None)
wheather_df['feels_like'] = wheather_df['weather_data'].apply(lambda x: wm.extract_feels_like(x['daily']) if 'daily' in x else None)
wheather_df['humidity'] = wheather_df['weather_data'].apply(lambda x: wm.extract_humidity(x['daily']) if 'daily' in x else None)
wheather_df['wind_speed'] = wheather_df['weather_data'].apply(lambda x: wm.extract_wind_speed(x['daily']) if 'daily' in x else None)
wheather_df['summary'] = wheather_df['weather_data'].apply(lambda x: wm.extract_summary(x['daily']) if 'daily' in x else None)
wheather_df['temp_day'] = wheather_df['weather_data'].apply(lambda x: wm.extract_temp_day(x['daily']) if 'daily' in x else None)
wheather_df['temp_min'] = wheather_df['weather_data'].apply(lambda x: wm.extract_temp_min(x['daily']) if 'daily' in x else None)
wheather_df['temp_max'] = wheather_df['weather_data'].apply(lambda x: wm.extract_temp_max(x['daily']) if 'daily' in x else None)
wheather_df['feels_like_day'] = wheather_df['weather_data'].apply(lambda x: wm.extract_feels_like_day(x['daily']) if 'daily' in x else None)
wheather_df['feels_like_night'] = wheather_df['weather_data'].apply(lambda x: wm.extract_feels_like_night(x['daily']) if 'daily' in x else None)
wheather_df['pop'] = wheather_df['weather_data'].apply(lambda x: wm.extract_pop(x['daily']) if 'daily' in x else None)
wheather_df['rain'] = wheather_df['weather_data'].apply(lambda x: wm.extract_rain_volume(x['daily']) if 'daily' in x else None)

# %%
wheather_df.head()
# Out:
#     place_id                                               city         lat  \
# 0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...  48.6359541
# 1  245319607  Saint-Malo, Ille-et-Vilaine, Bretagne, France ...   48.649518
# 2  244577445  Bayeux, Calvados, Normandie, France métropolit...  49.2764624
# 3   84845221  Le Havre, Seine-Maritime, Normandie, France mé...  49.4938975
# 4   84723446  Rouen, Seine-Maritime, Normandie, France métro...  49.4404591
#
#                   lon                                       weather_data  \
# 0  -1.511459954959514  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 1          -2.0260409  {'lat': 48.6495, 'lon': -2.026, 'timezone': 'E...
# 2          -0.7024738  {'lat': 49.2765, 'lon': -0.7025, 'timezone': '...
# 3           0.1079732  {'lat': 49.4939, 'lon': 0.108, 'timezone': 'Eu...
# 4           1.0939658  {'lat': 49.4405, 'lon': 1.094, 'timezone': 'Eu...
#
#                                                 date  \
# 0  [1699873200, 1699959600, 1700046000, 170013240...
# 1  [1699873200, 1699959600, 1700046000, 170013240...
# 2  [1699873200, 1699959600, 1700046000, 170013240...
# 3  [1699873200, 1699959600, 1700046000, 170013240...
# 4  [1699873200, 1699959600, 1700046000, 170013240...
#
#                                                 temp  \
# 0  [{'day': 15.98, 'min': 12.37, 'max': 16.24, 'n...
# 1  [{'day': 16.2, 'min': 12.24, 'max': 16.54, 'ni...
# 2  [{'day': 15.68, 'min': 11.3, 'max': 15.68, 'ni...
# 3  [{'day': 15.65, 'min': 11.74, 'max': 15.79, 'n...
# 4  [{'day': 16.16, 'min': 10.64, 'max': 16.34, 'n...
#
#                                           feels_like  \
# 0  [{'day': 16.04, 'night': 11.93, 'eve': 12.35, ...
# 1  [{'day': 16.15, 'night': 11.94, 'eve': 12.3, '...
# 2  [{'day': 15.65, 'night': 11.14, 'eve': 11.56, ...
# 3  [{'day': 15.59, 'night': 12.34, 'eve': 12.51, ...
# 4  [{'day': 16.08, 'night': 11.18, 'eve': 12.13, ...
#
#                            humidity  \
# 0  [92, 90, 83, 96, 65, 78, 75, 84]
# 1  [87, 86, 79, 84, 61, 81, 74, 82]
# 2  [90, 92, 76, 92, 63, 69, 76, 85]
# 3  [89, 94, 76, 91, 65, 69, 84, 88]
# 4  [86, 92, 77, 92, 71, 71, 75, 89]
#
#                                           wind_speed  \
# 0  [11.83, 11.01, 6.72, 10.87, 11.46, 7.79, 7.46,...
# 1  [11.92, 12.81, 8.5, 13.13, 13.68, 9.74, 8.49, ...
# 2  [11.75, 11.42, 8.25, 12.15, 11.28, 8.51, 8.59,...
# 3  [14.31, 13.04, 10.83, 15.28, 16.38, 11.09, 10....
# 4  [10.91, 10.4, 8.41, 12.11, 12.02, 5.71, 5.98, ...
#
#                                              summary  \
# 0  [Expect a day of partly cloudy with rain, Expe...
# 1  [Expect a day of partly cloudy with rain, Expe...
# 2  [Expect a day of partly cloudy with rain, Expe...
# 3  [Expect a day of partly cloudy with rain, The ...
# 4  [Expect a day of partly cloudy with rain, Expe...
#
#                                             temp_day  \
# 0  [15.98, 12.2, 12.37, 13.92, 11.69, 11.36, 14.2...
# 1  [16.2, 13.21, 12.63, 15.6, 12.14, 12.72, 14.41...
# 2  [15.68, 10.61, 12.57, 11.23, 11.16, 11.17, 14....
# 3  [15.65, 12.29, 12.49, 11.4, 11.15, 11.07, 13.5...
# 4  [16.16, 11.93, 12.44, 10.02, 10, 10.09, 14.54,...
#
#                                             temp_min  \
# 0    [12.37, 10.92, 9.27, 10, 8.94, 7.91, 10.17, 10]
# 1  [12.24, 11.76, 10.28, 10.51, 10.15, 9.23, 11.1...
# 2   [11.3, 10.55, 8.81, 9.2, 7.22, 8.51, 9.72, 9.96]
# 3  [11.74, 12.29, 11.32, 10.67, 10.52, 9.9, 10.69...
# 4  [10.64, 10.74, 8.81, 8.38, 6.08, 6.3, 8.65, 9.96]
#
#                                             temp_max  \
# 0  [16.24, 13.76, 12.98, 15.65, 11.69, 12.09, 14....
# 1  [16.54, 13.99, 13.25, 15.6, 12.14, 13.79, 14.5...
# 2  [15.68, 12.73, 12.83, 14.25, 11.16, 11.17, 14....
# 3  [15.79, 13.22, 12.73, 14.42, 11.46, 11.59, 13....
# 4  [16.34, 12.59, 12.66, 13.6, 10.92, 10.09, 14.5...
#
#                                       feels_like_day  \
# 0  [16.04, 11.83, 11.83, 13.87, 10.61, 10.59, 13....
# 1  [16.15, 12.83, 12.01, 15.41, 11, 12.16, 13.84,...
# 2  [15.65, 10.13, 11.87, 10.81, 9.98, 10.14, 13.5...
# 3  [15.59, 12.03, 11.78, 10.97, 10.02, 10.03, 13....
# 4  [16.08, 11.58, 11.75, 9.48, 6.58, 9.01, 14.01,...
#
#                                     feels_like_night  \
# 0  [11.93, 10.42, 9.44, 11.2, 7.88, 9.38, 9.67, 9...
# 1  [11.94, 11.24, 10.38, 11.48, 9.1, 11.29, 10.68...
# 2    [11.14, 10.12, 8.46, 10, 5.27, 9.88, 7.1, 6.53]
# 3  [12.34, 12.17, 10.67, 11.98, 9.93, 10, 11.55, ...
# 4  [11.18, 10.88, 7.8, 10.82, 5.2, 5.68, 7.55, 6.91]
#
#                               pop  \
# 0  [1, 1, 0.59, 1, 1, 0, 0.42, 1]
# 1  [1, 1, 0.45, 1, 1, 0, 0.34, 1]
# 2  [1, 1, 0, 1, 0.37, 0, 0.21, 1]
# 3      [1, 1, 1, 1, 1, 0, 0.2, 1]
# 4  [1, 1, 0.29, 1, 0.97, 0, 0, 1]
#
#                                              rain
# 0  [3.32, 10.39, 0.84, 7.78, 1.26, 0, 0.29, 1.52]
# 1   [2.35, 8.07, 0.39, 10.55, 0.5, 0, 0.13, 1.27]
# 2      [6.14, 9.95, 0, 5.14, 0.29, 0, 0.15, 1.24]
# 3    [8.59, 9.69, 4.44, 6.18, 1.05, 0, 0.3, 2.36]
# 4       [5.17, 6.24, 0.38, 5.3, 0.66, 0, 0, 1.35]

# %%
# Explode pour créer une ligne par date
# list('date', 'humidity',	'wind_speed', 'summary', 'temp_day', 'temp_min', 'temp_max','feels_like_day', 'feels_like_night', 'rain'))
wheather_df = wheather_df.explode(column=['date', 'humidity', 'wind_speed', 'temp_day', 'rain', 'summary', 'temp_min', 'temp_max','feels_like_day', 'feels_like_night', 'pop'])
wheather_df['date'] = pd.to_datetime(wheather_df['date'], unit='s')

# Réinitialisez l'index si nécessaire
wheather_df = wheather_df.reset_index(drop=False)

# %%
wheather_df.head()
# Out:
#    index   place_id                                               city  \
# 0      0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 1      0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 2      0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 3      0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 4      0  245061662  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
#
#           lat                 lon  \
# 0  48.6359541  -1.511459954959514
# 1  48.6359541  -1.511459954959514
# 2  48.6359541  -1.511459954959514
# 3  48.6359541  -1.511459954959514
# 4  48.6359541  -1.511459954959514
#
#                                         weather_data                date  \
# 0  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E... 2023-11-13 11:00:00
# 1  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E... 2023-11-14 11:00:00
# 2  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E... 2023-11-15 11:00:00
# 3  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E... 2023-11-16 11:00:00
# 4  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E... 2023-11-17 11:00:00
#
#                                                 temp  \
# 0  [{'day': 15.98, 'min': 12.37, 'max': 16.24, 'n...
# 1  [{'day': 15.98, 'min': 12.37, 'max': 16.24, 'n...
# 2  [{'day': 15.98, 'min': 12.37, 'max': 16.24, 'n...
# 3  [{'day': 15.98, 'min': 12.37, 'max': 16.24, 'n...
# 4  [{'day': 15.98, 'min': 12.37, 'max': 16.24, 'n...
#
#                                           feels_like humidity wind_speed  \
# 0  [{'day': 16.04, 'night': 11.93, 'eve': 12.35, ...       92      11.83
# 1  [{'day': 16.04, 'night': 11.93, 'eve': 12.35, ...       90      11.01
# 2  [{'day': 16.04, 'night': 11.93, 'eve': 12.35, ...       83       6.72
# 3  [{'day': 16.04, 'night': 11.93, 'eve': 12.35, ...       96      10.87
# 4  [{'day': 16.04, 'night': 11.93, 'eve': 12.35, ...       65      11.46
#
#                                              summary temp_day temp_min  \
# 0            Expect a day of partly cloudy with rain    15.98    12.37
# 1            Expect a day of partly cloudy with rain     12.2    10.92
# 2            Expect a day of partly cloudy with rain    12.37     9.27
# 3            Expect a day of partly cloudy with rain    13.92       10
# 4  The day will start with rain through the late ...    11.69     8.94
#
#   temp_max feels_like_day feels_like_night   pop   rain
# 0    16.24          16.04            11.93     1   3.32
# 1    13.76          11.83            10.42     1  10.39
# 2    12.98          11.83             9.44  0.59   0.84
# 3    15.65          13.87             11.2     1   7.78
# 4    11.69          10.61             7.88     1   1.26

# %%
# Drop the weather_data, temp, feels_like columns 
wheather_df = wheather_df.drop(['weather_data', 'temp', 'feels_like'], axis=1)

# %%
wheather_df = wheather_df.rename(columns={'humidity': 'humidity (%)', 'wind_speed': 'wind_speed (km/h)', 'temp_day': 'temp_day (°C)', 'temp_min': 'temp_min (°C)', 'temp_max': 'temp_max (°C)', 'feels_like_day': 'feels_like_day (°C)', 'feels_like_night': 'feels_like_night (°C)', 'rain': 'rain (mm)', 'pop': 'pop (%)'})

wheather_df = wheather_df.drop('index', axis=1)
wheather_df['date'] = wheather_df['date'].dt.date
wheather_df['city'] = wheather_df['city'].str.split(',').str[0]
wheather_df['pop (%)'] = wheather_df['pop (%)'].apply(lambda x: x*100)

# %%
wheather_df.head(11)
# Out:
#      place_id               city         lat                 lon        date  \
# 0   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-13
# 1   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-14
# 2   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-15
# 3   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-16
# 4   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-17
# 5   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-18
# 6   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-19
# 7   245061662  Mont Saint-Michel  48.6359541  -1.511459954959514  2023-11-20
# 8   245319607         Saint-Malo   48.649518          -2.0260409  2023-11-13
# 9   245319607         Saint-Malo   48.649518          -2.0260409  2023-11-14
# 10  245319607         Saint-Malo   48.649518          -2.0260409  2023-11-15
#
#    humidity (%) wind_speed (km/h)  \
# 0            92             11.83
# 1            90             11.01
# 2            83              6.72
# 3            96             10.87
# 4            65             11.46
# 5            78              7.79
# 6            75              7.46
# 7            84             10.03
# 8            87             11.92
# 9            86             12.81
# 10           79               8.5
#
#                                               summary temp_day (°C)  \
# 0             Expect a day of partly cloudy with rain         15.98
# 1             Expect a day of partly cloudy with rain          12.2
# 2             Expect a day of partly cloudy with rain         12.37
# 3             Expect a day of partly cloudy with rain         13.92
# 4   The day will start with rain through the late ...         11.69
# 5                   There will be partly cloudy today         11.36
# 6             Expect a day of partly cloudy with rain         14.29
# 7   You can expect partly cloudy in the morning, w...         11.23
# 8             Expect a day of partly cloudy with rain          16.2
# 9             Expect a day of partly cloudy with rain         13.21
# 10            Expect a day of partly cloudy with rain         12.63
#
#    temp_min (°C) temp_max (°C) feels_like_day (°C) feels_like_night (°C)  \
# 0          12.37         16.24               16.04                 11.93
# 1          10.92         13.76               11.83                 10.42
# 2           9.27         12.98               11.83                  9.44
# 3             10         15.65               13.87                  11.2
# 4           8.94         11.69               10.61                  7.88
# 5           7.91         12.09               10.59                  9.38
# 6          10.17         14.29               13.73                  9.67
# 7             10         11.59                10.6                  9.95
# 8          12.24         16.54               16.15                 11.94
# 9          11.76         13.99               12.83                 11.24
# 10         10.28         13.25               12.01                 10.38
#
#     pop (%) rain (mm)
# 0     100.0      3.32
# 1     100.0     10.39
# 2      59.0      0.84
# 3     100.0      7.78
# 4     100.0      1.26
# 5       0.0         0
# 6      42.0      0.29
# 7     100.0      1.52
# 8     100.0      2.35
# 9     100.0      8.07
# 10     45.0      0.39

# %%
# CSV
wheather_df.to_csv('wheather_df.csv', index=False)

# %% [markdown]
# Bookin.com scraping

# %%
# !python booking_spider.py
# Out:
# 2023-11-13 19:43:46 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-11-13 19:43:47 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.11.5, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:29:11) [MSC v.1935 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.19045-SP0
# 2023-11-13 19:43:47 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-13 19:43:47 [py.warnings] WARNING: c:\Users\nicol\miniconda3\envs\data_env\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-13 19:43:47 [scrapy.extensions.telnet] INFO: Telnet Password: 1b7bdcfcc384c32a
# 2023-11-13 19:43:49 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-13 19:43:49 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2023-11-13 19:43:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-13 19:43:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-13 19:43:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-13 19:43:50 [scrapy.core.engine] INFO: Spider opened
# 2023-11-13 19:43:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-13 19:43:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-13 19:44:50 [scrapy.extensions.logstats] INFO: Crawled 248 pages (at 248 pages/min), scraped 228 items (at 228 items/min)
# 2023-11-13 19:45:50 [scrapy.extensions.logstats] INFO: Crawled 510 pages (at 262 pages/min), scraped 489 items (at 261 items/min)
# 2023-11-13 19:46:50 [scrapy.extensions.logstats] INFO: Crawled 768 pages (at 258 pages/min), scraped 733 items (at 244 items/min)
# 2023-11-13 19:47:24 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-13 19:47:24 [scrapy.extensions.feedexport] INFO: Stored json feed (875 items) in: json/hotel.json
# 2023-11-13 19:47:24 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1804961,
#  'downloader/request_count': 980,
#  'downloader/request_method_count/GET': 980,
#  'downloader/response_bytes': 219471920,
#  'downloader/response_count': 980,
#  'downloader/response_status_count/200': 910,
#  'downloader/response_status_count/302': 70,
#  'elapsed_time_seconds': 214.106459,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 13, 18, 47, 24, 630307, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 1130650572,
#  'httpcompression/response_count': 910,
#  'item_scraped_count': 875,
#  'log_count/INFO': 14,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 910,
#  'scheduler/dequeued': 980,
#  'scheduler/dequeued/memory': 980,
#  'scheduler/enqueued': 980,
#  'scheduler/enqueued/memory': 980,
#  'start_time': datetime.datetime(2023, 11, 13, 18, 43, 50, 523848, tzinfo=datetime.timezone.utc)}
# 2023-11-13 19:47:24 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
hotel_df = pd.read_json('json/hotel.json')

# %%
# suppression des caractères d'échappement 
hotel_df['hotel_address'] = hotel_df['hotel_address'].replace(r'\n', ' ', regex=True)

# %%
hotel_df['lat_lon_hotel'] = hotel_df['lat_lon_hotel'].str.split(',')

# %%
hotel_df['lat_hotel'] = hotel_df['lat_lon_hotel'].apply(lambda x: x[0])
hotel_df['lon_hotel'] = hotel_df['lat_lon_hotel'].apply(lambda x: x[1])

# %%
hotel_df = hotel_df.drop('lat_lon_hotel', axis=1)
hotel_df = hotel_df.rename(columns={"city_to_visit": "city"})

# %%
hotel_df.head()
# Out:
#          city                                 hotel_name  \
# 0      Amiens                             Le Green suite
# 1      Amiens                              Les Augustins
# 2  Saint-Malo                    La Maison des Armateurs
# 3      Amiens  Studio Spa Privatif NETFLIX Unique Amiens
# 4    Besançon       Hôtel Fontaine Argent - Centre Ville
#
#                                        hotel_address hotel_general_review  \
# 0            42 Rue Bonvallet, 80080 Amiens, France                  None
# 1         8 Rue des Augustins, 80000 Amiens, France                  Good
# 2   6, Grand Rue, Intra Muros, 35400 Saint Malo, ...            Very good
# 3           53 Rue Debaussaux, 80000 Amiens, France              Fabulous
# 4   23 Avenue Fontaine-Argent, 25000 Besançon, Fr...            Very good
#
#    hotel_rating numbers_of_reviews  \
# 0           NaN               None
# 1           7.8        989 reviews
# 2           8.5      1,347 reviews
# 3           8.6        119 reviews
# 4           8.3        461 reviews
#
#                                     hotel_facilities  \
# 0  [Free WiFi, Free WiFi, Kitchenware, Kitchen, W...
# 1  [Parking, Free WiFi, Family rooms, Non-smoking...
# 2  [Private parking, Family rooms, Free WiFi, Non...
# 3  [Free parking, Free WiFi, Spa and wellness cen...
# 4  [Private parking, Free WiFi, Family rooms, Non...
#
#                                    hotel_description  \
# 0  Set 3.6 km from Amiens Train Station, 2.8 km f...
# 1  Situated 700 metres from Amiens Train Station,...
# 2  Set in the historical centre of Saint-Malo, th...
# 3  Studio Spa Privatif NETFLIX Unique Amiens has ...
# 4  Hôtel Fontaine Argent - Centre Ville is set in...
#
#                                    url_booking_hotel    lat_hotel    lon_hotel
# 0  https://www.booking.com/hotel/fr/le-green-suit...  49.90194410   2.28848990
# 1  https://www.booking.com/hotel/fr/les-augustins...  49.89422900   2.30577800
# 2  https://www.booking.com/hotel/fr/la-maison-des...  48.64920520  -2.02463329
# 3  https://www.booking.com/hotel/fr/studio-spa-pr...  49.90016840   2.28609340
# 4  https://www.booking.com/hotel/fr/fontaine-arge...  47.24614600   6.03318600

# %%
# isna() pour compter les NaN dans le DataFrame
nan_counts = hotel_df.isna().sum()
print(nan_counts)
# Out:
# city                     0
# hotel_name               0
# hotel_address            0
# hotel_general_review    49
# hotel_rating            88
# numbers_of_reviews      49
# hotel_facilities         0
# hotel_description        0
# url_booking_hotel        0
# lat_hotel                0
# lon_hotel                0
# dtype: int64
#
# city                     0
# hotel_name               0
# hotel_address            0
# hotel_general_review    49
# hotel_rating            88
# numbers_of_reviews      49
# hotel_facilities         0
# hotel_description        0
# url_booking_hotel        0
# lat_hotel                0
# lon_hotel                0
# dtype: int64

# %%
hotel_df[["lat_hotel", "lon_hotel"]] = hotel_df[["lat_hotel", "lon_hotel"]].astype('float')

# %%
# hotel df to csv to feed S3
hotel_df = hotel_df.sort_values(by="hotel_rating", ascending=False)

hotel_df.head()
# Out:
#                 city                                         hotel_name  \
# 184           Annecy                                        Cosy studio
# 836  Aix-en-Provence              T2 calme centre historique AIX EN PCE
# 803             Uzès                                   La DAME de FLAUX
# 548          Bayonne  Appartement Bayonne, 2 pièces, 4 personnes - F...
# 637        Montauban              Logement complet - Un Air de campagne
#
#                                          hotel_address hotel_general_review  \
# 184            13 Rue du Vernay, 74960 Annecy, France           Exceptional
# 836    4 Rue Duperrier, 13100 Aix-en-Provence, France           Exceptional
# 803              7 Rue Pelisserie, 30700 Uzès, France           Exceptional
# 548   13 Boulevard Alsace Lorraine, 64100 Bayonne, ...          Exceptional
# 637   1875 Chemin de Pinceguerre, 82000 Montauban, ...          Exceptional
#
#      hotel_rating numbers_of_reviews  \
# 184          10.0           1 review
# 836          10.0           1 review
# 803          10.0          8 reviews
# 548          10.0          2 reviews
# 637          10.0           1 review
#
#                                       hotel_facilities  \
# 184  [Non-smoking rooms, Terrace, Non-smoking rooms...
# 836  [Free WiFi, Breakfast, Free WiFi, Breakfast, K...
# 803  [Free WiFi, Family rooms, Non-smoking rooms, F...
# 548  [Free WiFi, Free WiFi, Oven, Kitchen, Dishwash...
# 637  [Free parking, Free WiFi, Family rooms, Facili...
#
#                                      hotel_description  \
# 184  Situated 36 km from Bourget Lake, 41 km from S...
# 836  Set in Aix-en-Provence, 30 km from Marseille S...
# 803  Situated in Uzès, 38 km from Avignon Central S...
# 548  Appartement Bayonne, 2 pièces, 4 personnes - F...
# 637  Logement complet - Un Air de campagne is a sus...
#
#                                      url_booking_hotel  lat_hotel  lon_hotel
# 184  https://www.booking.com/hotel/fr/cosy-studio-c...  45.907381   6.111990
# 836  https://www.booking.com/hotel/fr/t2-calme-cent...  43.529539   5.443436
# 803  https://www.booking.com/hotel/fr/la-dame-de-fl...  44.012050   4.419244
# 548  https://www.booking.com/hotel/fr/appartement-b...  43.494974  -1.468773
# 637  https://www.booking.com/hotel/fr/logement-comp...  43.996509   1.405061

# %%
# Création d'une session aws
session = boto3.Session(aws_access_key_id="AKIAXKIPKVIFPD3PXQUE", 
                        aws_secret_access_key="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")
s3 = session.resource("s3")

# %%
weather_csv_df = pd.read_csv('wheather_df.csv')
weather_csv_df.head()
# Out:
#     place_id               city        lat      lon        date  humidity (%)  \
# 0  245061662  Mont Saint-Michel  48.635954 -1.51146  2023-11-13            92
# 1  245061662  Mont Saint-Michel  48.635954 -1.51146  2023-11-14            90
# 2  245061662  Mont Saint-Michel  48.635954 -1.51146  2023-11-15            83
# 3  245061662  Mont Saint-Michel  48.635954 -1.51146  2023-11-16            96
# 4  245061662  Mont Saint-Michel  48.635954 -1.51146  2023-11-17            65
#
#    wind_speed (km/h)                                            summary  \
# 0              11.83            Expect a day of partly cloudy with rain
# 1              11.01            Expect a day of partly cloudy with rain
# 2               6.72            Expect a day of partly cloudy with rain
# 3              10.87            Expect a day of partly cloudy with rain
# 4              11.46  The day will start with rain through the late ...
#
#    temp_day (°C)  temp_min (°C)  temp_max (°C)  feels_like_day (°C)  \
# 0          15.98          12.37          16.24                16.04
# 1          12.20          10.92          13.76                11.83
# 2          12.37           9.27          12.98                11.83
# 3          13.92          10.00          15.65                13.87
# 4          11.69           8.94          11.69                10.61
#
#    feels_like_night (°C)  pop (%)  rain (mm)
# 0                  11.93    100.0       3.32
# 1                  10.42    100.0      10.39
# 2                   9.44     59.0       0.84
# 3                  11.20    100.0       7.78
# 4                   7.88    100.0       1.26

# %%
city_unique_df = weather_csv_df.drop_duplicates(subset=['city'], keep='first')
top_5_city_temp_df = city_unique_df.sort_values(by="feels_like_day (°C)", ascending=False).head(5)
city_csv_df = top_5_city_temp_df.to_csv('city_top_5.csv')

# %%
s3.Bucket("jedha-data-weather").upload_file('city_top_5.csv', 'city_top_5.csv') # type: ignore

# %%
top_city_list = top_5_city_temp_df["city"].tolist()
mask_hotel_city = hotel_df["city"].isin(top_city_list)
filtered_hotel_city_df = hotel_df[mask_hotel_city]
csv_hotel = filtered_hotel_city_df.to_csv('hotel_top_20.csv')
s3.Bucket("jedha-data-weather").upload_file('hotel_top_20.csv', 'hotel_top_20.csv') # type: ignore

# %% [markdown]
# ### Get csv from s3
# ##### city_top_5.csv
# ##### hotel_top_20.csv

# %%
# recuperation du fichier csv dans un s3
BUCKET_NAME = "jedha-data-weather"
from smart_open import smart_open

city_object_key = 'city_top_5.csv'
hotel_object_key = 'hotel_top_20.csv'

city_path = 's3://{}:{}@{}/{}'.format("AKIAXKIPKVIFPD3PXQUE", "AlSwwStdYzEHQrNZpDx4g8fPBKaCJIK3S53AOxxw", BUCKET_NAME, city_object_key)

hotel_path = 's3://{}:{}@{}/{}'.format("AKIAXKIPKVIFPD3PXQUE", "AlSwwStdYzEHQrNZpDx4g8fPBKaCJIK3S53AOxxw", BUCKET_NAME, hotel_object_key)

# %%
city_to_5_df = pd.read_csv(smart_open(city_path), index_col=0)
hotel_top_20_df = pd.read_csv(smart_open(hotel_path), index_col=0)

# %%
city_hotel_df = pd.merge(city_to_5_df, hotel_top_20_df, on='city')

# %%
city_hotel_df.dropna()
# Out:
#       place_id       city        lat       lon        date  humidity (%)  \
# 0     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 1     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 2     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 3     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 4     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# ..         ...        ...        ...       ...         ...           ...
# 120  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 121  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 122  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 123  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 124  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
#
#      wind_speed (km/h)                                  summary  \
# 0                 2.14        There will be partly cloudy today
# 1                 2.14        There will be partly cloudy today
# 2                 2.14        There will be partly cloudy today
# 3                 2.14        There will be partly cloudy today
# 4                 2.14        There will be partly cloudy today
# ..                 ...                                      ...
# 120               4.87  Expect a day of partly cloudy with rain
# 121               4.87  Expect a day of partly cloudy with rain
# 122               4.87  Expect a day of partly cloudy with rain
# 123               4.87  Expect a day of partly cloudy with rain
# 124               4.87  Expect a day of partly cloudy with rain
#
#      temp_day (°C)  temp_min (°C)  ...  \
# 0            22.42          15.07  ...
# 1            22.42          15.07  ...
# 2            22.42          15.07  ...
# 3            22.42          15.07  ...
# 4            22.42          15.07  ...
# ..             ...            ...  ...
# 120          19.90          15.30  ...
# 121          19.90          15.30  ...
# 122          19.90          15.30  ...
# 123          19.90          15.30  ...
# 124          19.90          15.30  ...
#
#                                             hotel_name  \
# 0    Matisse studio in centre near beach w/ balcony...
# 1    L'Escale de Collioure - Climatisé, parking pri...
# 2                          T3 piscine clim wifi garage
# 3                                 Lumières à Collioure
# 4                              Les Suites de Collioure
# ..                                                 ...
# 120       Sure Hotel by Best Western Biarritz Aeroport
# 121               Lagrange Vacances Les Patios Eugénie
# 122             Nemea Appart'hôtel Les Hauts de Milady
# 123                                Brit Hotel Marbella
# 124                        Radisson Blu Hotel Biarritz
#
#                                          hotel_address  hotel_general_review  \
# 0         8 Place du 18 Juin, 66190 Collioure, France            Exceptional
# 1     24 Rte Impériale - Appartement A306 -, 66190 ...           Exceptional
# 2                4 Julien Py, 66190 Collioure, France            Exceptional
# 3        1 Rue Saint-Vincent, 66190 Collioure, France                 Superb
# 4     16 avenue du Général de Gaulle, 66190 Colliou...                Superb
# ..                                                 ...                   ...
# 120   24 boulevard marcel dassault, 64200 Biarritz,...                  Good
# 121   30/32 avenue de la reine Victoria, 64200 Biar...                  Good
# 122    24 Avenue de la Milady, 64200 Biarritz, France                   Good
# 123      11 Rue Du Port Vieux, 64200 Biarritz, France                   Good
# 124     1 Carrefour Helianthe, 64200 Biarritz, France                   Good
#
#      hotel_rating  numbers_of_reviews  \
# 0            10.0           2 reviews
# 1            10.0           2 reviews
# 2             9.5           2 reviews
# 3             9.3           9 reviews
# 4             9.3         285 reviews
# ..            ...                 ...
# 120           7.8       2,150 reviews
# 121           7.7         323 reviews
# 122           7.6       1,843 reviews
# 123           7.5       1,140 reviews
# 124           7.5       1,943 reviews
#
#                                       hotel_facilities  \
# 0    ['Free WiFi', 'Non-smoking rooms', 'Free WiFi'...
# 1    ['Free parking', 'Free WiFi', 'Non-smoking roo...
# 2    ['Outdoor swimming pool', 'Free parking', 'Fre...
# 3    ['Free WiFi', 'Free WiFi', 'Kitchen', 'Dishwas...
# 4    ['Parking', 'Free WiFi', 'Family rooms', 'Non-...
# ..                                                 ...
# 120  ['Free parking', 'Free WiFi', 'Family rooms', ...
# 121  ['Outdoor swimming pool', 'Private parking', '...
# 122  ['2 swimming pools', 'Private parking', 'Free ...
# 123  ['Parking', 'Free WiFi', 'Beachfront', 'Family...
# 124  ['Outdoor swimming pool', 'Private parking', '...
#
#                                      hotel_description  \
# 0    Situated in Collioure, 90 metres from Boramar ...
# 1    Set in Collioure and only 500 metres from Regu...
# 2    Situated in Collioure, T3 piscine clim wifi ga...
# 3    A recently renovated property, Lumières à Coll...
# 4    Located in Collioure, 200 metres from Port Ava...
# ..                                                 ...
# 120  Sure Hotel by Best Western Biarritz Aeroport i...
# 121  Lagrange Vacances Les Patios Eugénie is a styl...
# 122  Boasting a seasonal outdoor pool, a hot tub an...
# 123  Located in Biarritz, Brit Hotel Marbella is in...
# 124  Located in the centre of Biarritz, the Radisso...
#
#                                      url_booking_hotel  lat_hotel lon_hotel
# 0    https://www.booking.com/hotel/fr/matisse-studi...  42.527032  3.084534
# 1    https://www.booking.com/hotel/fr/escale-de-col...  42.521823  3.093709
# 2    https://www.booking.com/hotel/fr/t3-piscine-cl...  42.526992  3.075032
# 3    https://www.booking.com/hotel/fr/lumieres-a-co...  42.527102  3.084495
# 4    https://www.booking.com/hotel/fr/les-suites-de...  42.524390  3.082726
# ..                                                 ...        ...       ...
# 120  https://www.booking.com/hotel/fr/amaryshotel.e...  43.472208 -1.534899
# 121  https://www.booking.com/hotel/fr/lagrange-pres...  43.485045 -1.551326
# 122  https://www.booking.com/hotel/fr/nemea-appart-...  43.470225 -1.567847
# 123  https://www.booking.com/hotel/fr/citotelmarbel...  43.482049 -1.565849
# 124  https://www.booking.com/hotel/fr/radisson-blu-...  43.478272 -1.564691
#
# [124 rows x 25 columns]

# %%
city_hotel_csv_df = city_hotel_df.to_csv('top_city_hotel.csv')

# %%
s3.Bucket("jedha-data-weather").upload_file('top_city_hotel.csv', 'top_city_hotel.csv') # type: ignore

# %%
top_city_hotel_object_key = 'top_city_hotel.csv'

top_city_hotel_path = 's3://{}:{}@{}/{}'.format("AKIAXKIPKVIFPD3PXQUE", "AlSwwStdYzEHQrNZpDx4g8fPBKaCJIK3S53AOxxw", BUCKET_NAME, top_city_hotel_object_key)

top_city_hotel_df = pd.read_csv(smart_open(top_city_hotel_path), index_col=0)

# %%
top_city_hotel_df
# Out:
#       place_id       city        lat       lon        date  humidity (%)  \
# 0     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 1     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 2     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 3     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# 4     72068913  Collioure  42.525050  3.083155  2023-11-13            53
# ..         ...        ...        ...       ...         ...           ...
# 120  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 121  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 122  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 123  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
# 124  250442744   Biarritz  43.483252 -1.559278  2023-11-13            73
#
#      wind_speed (km/h)                                  summary  \
# 0                 2.14        There will be partly cloudy today
# 1                 2.14        There will be partly cloudy today
# 2                 2.14        There will be partly cloudy today
# 3                 2.14        There will be partly cloudy today
# 4                 2.14        There will be partly cloudy today
# ..                 ...                                      ...
# 120               4.87  Expect a day of partly cloudy with rain
# 121               4.87  Expect a day of partly cloudy with rain
# 122               4.87  Expect a day of partly cloudy with rain
# 123               4.87  Expect a day of partly cloudy with rain
# 124               4.87  Expect a day of partly cloudy with rain
#
#      temp_day (°C)  temp_min (°C)  ...  \
# 0            22.42          15.07  ...
# 1            22.42          15.07  ...
# 2            22.42          15.07  ...
# 3            22.42          15.07  ...
# 4            22.42          15.07  ...
# ..             ...            ...  ...
# 120          19.90          15.30  ...
# 121          19.90          15.30  ...
# 122          19.90          15.30  ...
# 123          19.90          15.30  ...
# 124          19.90          15.30  ...
#
#                                             hotel_name  \
# 0    Matisse studio in centre near beach w/ balcony...
# 1    L'Escale de Collioure - Climatisé, parking pri...
# 2                          T3 piscine clim wifi garage
# 3                                 Lumières à Collioure
# 4                              Les Suites de Collioure
# ..                                                 ...
# 120       Sure Hotel by Best Western Biarritz Aeroport
# 121               Lagrange Vacances Les Patios Eugénie
# 122             Nemea Appart'hôtel Les Hauts de Milady
# 123                                Brit Hotel Marbella
# 124                        Radisson Blu Hotel Biarritz
#
#                                          hotel_address  hotel_general_review  \
# 0         8 Place du 18 Juin, 66190 Collioure, France            Exceptional
# 1     24 Rte Impériale - Appartement A306 -, 66190 ...           Exceptional
# 2                4 Julien Py, 66190 Collioure, France            Exceptional
# 3        1 Rue Saint-Vincent, 66190 Collioure, France                 Superb
# 4     16 avenue du Général de Gaulle, 66190 Colliou...                Superb
# ..                                                 ...                   ...
# 120   24 boulevard marcel dassault, 64200 Biarritz,...                  Good
# 121   30/32 avenue de la reine Victoria, 64200 Biar...                  Good
# 122    24 Avenue de la Milady, 64200 Biarritz, France                   Good
# 123      11 Rue Du Port Vieux, 64200 Biarritz, France                   Good
# 124     1 Carrefour Helianthe, 64200 Biarritz, France                   Good
#
#      hotel_rating  numbers_of_reviews  \
# 0            10.0           2 reviews
# 1            10.0           2 reviews
# 2             9.5           2 reviews
# 3             9.3           9 reviews
# 4             9.3         285 reviews
# ..            ...                 ...
# 120           7.8       2,150 reviews
# 121           7.7         323 reviews
# 122           7.6       1,843 reviews
# 123           7.5       1,140 reviews
# 124           7.5       1,943 reviews
#
#                                       hotel_facilities  \
# 0    ['Free WiFi', 'Non-smoking rooms', 'Free WiFi'...
# 1    ['Free parking', 'Free WiFi', 'Non-smoking roo...
# 2    ['Outdoor swimming pool', 'Free parking', 'Fre...
# 3    ['Free WiFi', 'Free WiFi', 'Kitchen', 'Dishwas...
# 4    ['Parking', 'Free WiFi', 'Family rooms', 'Non-...
# ..                                                 ...
# 120  ['Free parking', 'Free WiFi', 'Family rooms', ...
# 121  ['Outdoor swimming pool', 'Private parking', '...
# 122  ['2 swimming pools', 'Private parking', 'Free ...
# 123  ['Parking', 'Free WiFi', 'Beachfront', 'Family...
# 124  ['Outdoor swimming pool', 'Private parking', '...
#
#                                      hotel_description  \
# 0    Situated in Collioure, 90 metres from Boramar ...
# 1    Set in Collioure and only 500 metres from Regu...
# 2    Situated in Collioure, T3 piscine clim wifi ga...
# 3    A recently renovated property, Lumières à Coll...
# 4    Located in Collioure, 200 metres from Port Ava...
# ..                                                 ...
# 120  Sure Hotel by Best Western Biarritz Aeroport i...
# 121  Lagrange Vacances Les Patios Eugénie is a styl...
# 122  Boasting a seasonal outdoor pool, a hot tub an...
# 123  Located in Biarritz, Brit Hotel Marbella is in...
# 124  Located in the centre of Biarritz, the Radisso...
#
#                                      url_booking_hotel  lat_hotel lon_hotel
# 0    https://www.booking.com/hotel/fr/matisse-studi...  42.527032  3.084534
# 1    https://www.booking.com/hotel/fr/escale-de-col...  42.521823  3.093709
# 2    https://www.booking.com/hotel/fr/t3-piscine-cl...  42.526992  3.075032
# 3    https://www.booking.com/hotel/fr/lumieres-a-co...  42.527102  3.084495
# 4    https://www.booking.com/hotel/fr/les-suites-de...  42.524390  3.082726
# ..                                                 ...        ...       ...
# 120  https://www.booking.com/hotel/fr/amaryshotel.e...  43.472208 -1.534899
# 121  https://www.booking.com/hotel/fr/lagrange-pres...  43.485045 -1.551326
# 122  https://www.booking.com/hotel/fr/nemea-appart-...  43.470225 -1.567847
# 123  https://www.booking.com/hotel/fr/citotelmarbel...  43.482049 -1.565849
# 124  https://www.booking.com/hotel/fr/radisson-blu-...  43.478272 -1.564691
#
# [125 rows x 25 columns]

# %% [markdown]
# ### SQL DB

# %%
from sqlalchemy import create_engine, text


engine = create_engine('sqlite:///:memory:', echo=True)

# %%
top_city_hotel_df.to_sql("top_city_hotel", engine)
# Out:
# 2023-11-13 19:47:47,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-13 19:47:47,069 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("top_city_hotel")
# 2023-11-13 19:47:47,071 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-11-13 19:47:47,082 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("top_city_hotel")
# 2023-11-13 19:47:47,083 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-11-13 19:47:47,093 INFO sqlalchemy.engine.Engine
# CREATE TABLE top_city_hotel (
# 	"index" BIGINT,
# 	place_id BIGINT,
# 	city TEXT,
# 	lat FLOAT,
# 	lon FLOAT,
# 	date TEXT,
# 	"humidity (%)" BIGINT,
# 	"wind_speed (km/h)" FLOAT,
# 	summary TEXT,
# 	"temp_day (°C)" FLOAT,
# 	"temp_min (°C)" FLOAT,
# 	"temp_max (°C)" FLOAT,
# 	"feels_like_day (°C)" FLOAT,
# 	"feels_like_night (°C)" FLOAT,
# 	"pop (%)" FLOAT,
# 	"rain (mm)" FLOAT,
# 	hotel_name TEXT,
# 	hotel_address TEXT,
# 	hotel_general_review TEXT,
# 	hotel_rating FLOAT,
# 	numbers_of_reviews TEXT,
# 	hotel_facilities TEXT,
# 	hotel_description TEXT,
# 	url_booking_hotel TEXT,
# 	lat_hotel FLOAT,
# 	lon_hotel FLOAT
# )
#
#
# 2023-11-13 19:47:47,094 INFO sqlalchemy.engine.Engine [no key 0.00127s] ()
# 2023-11-13 19:47:47,097 INFO sqlalchemy.engine.Engine CREATE INDEX ix_top_city_hotel_index ON top_city_hotel ("index")
# 2023-11-13 19:47:47,099 INFO sqlalchemy.engine.Engine [no key 0.00158s] ()
# 2023-11-13 19:47:47,123 INFO sqlalchemy.engine.Engine INSERT INTO top_city_hotel ("index", place_id, city, lat, lon, date, "humidity (%)", "wind_speed (km/h)", summary, "temp_day (°C)", "temp_min (°C)", "temp_max (°C)", "feels_like_day (°C)", "feels_like_night (°C)", "pop (%)", "rain (mm)", hotel_name, hotel_address, hotel_general_review, hotel_rating, numbers_of_reviews, hotel_facilities, hotel_description, url_booking_hotel, lat_hotel, lon_hotel) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-11-13 19:47:47,126 INFO sqlalchemy.engine.Engine [generated in 0.01239s] [(0, 72068913, 'Collioure', 42.52505, 3.0831554, '2023-11-13', 53, 2.14, 'There will be partly cloudy today', 22.42, 15.07, 22.42, 22.1, 17.36, 0.0, 0.0, 'Matisse studio in centre near beach w/ balcony, AC', ' 8 Place du 18 Juin, 66190 Collioure, France ', 'Exceptional', 10.0, '2 reviews', "['Free WiFi', 'Non-smoking rooms', 'Free WiFi', 'Non-smoking rooms', 'Dining table', 'Coffee machine', 'Stovetop', 'Oven', 'Kitchenware', 'Electric k ... (492 characters truncated) ... ', 'Air conditioning', 'Non-smoking throughout', 'Heating', 'Non-smoking rooms', 'Fire extinguishers', 'Smoke alarms', 'German', 'English', 'French']", 'Situated in Collioure, 90 metres from Boramar Beach and 200 metres from Nord Beach, Matisse studio in centre near beach w/ balcony, AC features air-c ... (613 characters truncated) ... rse is 23 km from the property. The nearest airport is Perpignan - Rivesaltes Airport, 41 km from Matisse studio in centre near beach w/ balcony, AC.', 'https://www.booking.com/hotel/fr/matisse-studio-in-centre-near-beach-w-balcony-ac.en-gb.html?label=gen173nr-1FEgZzZWFyY2goggI46AdIM1gEaE2IAQGYAQm4AQr ... (214 characters truncated) ... dults=2&no_rooms=1&group_children=0&req_children=0&hpos=25&hapos=25&sr_order=popularity&srpvid=795283f06b090236&srepoch=1699901154&from=searchresults', 42.5270323, 3.0845335), (1, 72068913, 'Collioure', 42.52505, 3.0831554, '2023-11-13', 53, 2.14, 'There will be partly cloudy today', 22.42, 15.07, 22.42, 22.1, 17.36, 0.0, 0.0, "L'Escale de Collioure - Climatisé, parking privé sécurisé, vue mer", ' 24 Rte Impériale - Appartement A306 -, 66190 Collioure, France ', 'Exceptional', 10.0, '2 reviews', '[\'Free parking\', \'Free WiFi\', \'Non-smoking rooms\', \'Terrace\', \'Free parking\', \'Free WiFi\', \'Non-smoking rooms\', \'Terrace\', \'Parking  ... (467 characters truncated) ... , \'Sea view\', \'Air conditioning\', \'Non-smoking throughout\', \'Heating\', \'Lift\', \'Non-smoking rooms\', \'English\', \'Spanish\', \'French\']', "Set in Collioure and only 500 metres from Reguers Beach, L'Escale de Collioure - Climatisé, parking privé sécurisé, vue mer offers accommodation with ... (463 characters truncated) ... m the property. The nearest airport is Perpignan - Rivesaltes Airport, 43 km from L'Escale de Collioure - Climatisé, parking privé sécurisé, vue mer.", 'https://www.booking.com/hotel/fr/escale-de-collioure-climatise-parking-prive-securise-vue-mer.en-gb.html?label=gen173nr-1FEgZzZWFyY2goggI46AdIM1gEaE2 ... (226 characters truncated) ... dults=2&no_rooms=1&group_children=0&req_children=0&hpos=20&hapos=20&sr_order=popularity&srpvid=795283f06b090236&srepoch=1699901154&from=searchresults', 42.52182291, 3.09370921), (2, 72068913, 'Collioure', 42.52505, 3.0831554, '2023-11-13', 53, 2.14, 'There will be partly cloudy today', 22.42, 15.07, 22.42, 22.1, 17.36, 0.0, 0.0, 'T3 piscine clim wifi garage', ' 4 Julien Py, 66190 Collioure, France ', 'Exceptional', 9.5, '2 reviews', '[\'Outdoor swimming pool\', \'Free parking\', \'Free WiFi\', \'Non-smoking rooms\', \'Terrace\', \'Outdoor swimming pool\', \'Free parking\', \'Free  ... (1092 characters truncated) ... ing area\', \'Air conditioning\', \'Non-smoking throughout\', \'Heating\', \'Soundproof rooms\', \'Non-smoking rooms\', \'Smoke alarms\', \'French\']', 'Situated in Collioure, T3 piscine clim wifi garage features accommodation with private pool, free WiFi and free private parking for guests who drive. ... (522 characters truncated) ... ll Beach, Collioure Royal Castle and Casino Collioure. The nearest airport is Perpignan - Rivesaltes Airport, 33 km from T3 piscine clim wifi garage.', 'https://www.booking.com/hotel/fr/t3-piscine-clim-wifi-garage.en-gb.html?label=gen173nr-1FEgZzZWFyY2goggI46AdIM1gEaE2IAQGYAQm4AQrIAQXYAQHoAQH4AQOIAgGo ... (193 characters truncated) ... dults=2&no_rooms=1&group_children=0&req_children=0&hpos=24&hapos=24&sr_order=popularity&srpvid=795283f06b0 ...
# 2023-11-13 19:47:47,132 INFO sqlalchemy.engine.Engine COMMIT
# 125

# %%
# Connect DB
conn = engine.connect()

# %%
data = text("SELECT * FROM top_city_hotel")

# %%
pd.read_sql_query(data, conn).head()
# Out:
# 2023-11-13 19:47:47,197 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-13 19:47:47,199 INFO sqlalchemy.engine.Engine SELECT * FROM top_city_hotel
# 2023-11-13 19:47:47,200 INFO sqlalchemy.engine.Engine [generated in 0.00311s] ()
#    index  place_id       city       lat       lon        date  humidity (%)  \
# 0      0  72068913  Collioure  42.52505  3.083155  2023-11-13            53
# 1      1  72068913  Collioure  42.52505  3.083155  2023-11-13            53
# 2      2  72068913  Collioure  42.52505  3.083155  2023-11-13            53
# 3      3  72068913  Collioure  42.52505  3.083155  2023-11-13            53
# 4      4  72068913  Collioure  42.52505  3.083155  2023-11-13            53
#
#    wind_speed (km/h)                            summary  temp_day (°C)  ...  \
# 0               2.14  There will be partly cloudy today          22.42  ...
# 1               2.14  There will be partly cloudy today          22.42  ...
# 2               2.14  There will be partly cloudy today          22.42  ...
# 3               2.14  There will be partly cloudy today          22.42  ...
# 4               2.14  There will be partly cloudy today          22.42  ...
#
#                                           hotel_name  \
# 0  Matisse studio in centre near beach w/ balcony...
# 1  L'Escale de Collioure - Climatisé, parking pri...
# 2                        T3 piscine clim wifi garage
# 3                               Lumières à Collioure
# 4                            Les Suites de Collioure
#
#                                        hotel_address  hotel_general_review  \
# 0       8 Place du 18 Juin, 66190 Collioure, France            Exceptional
# 1   24 Rte Impériale - Appartement A306 -, 66190 ...           Exceptional
# 2              4 Julien Py, 66190 Collioure, France            Exceptional
# 3      1 Rue Saint-Vincent, 66190 Collioure, France                 Superb
# 4   16 avenue du Général de Gaulle, 66190 Colliou...                Superb
#
#    hotel_rating  numbers_of_reviews  \
# 0          10.0           2 reviews
# 1          10.0           2 reviews
# 2           9.5           2 reviews
# 3           9.3           9 reviews
# 4           9.3         285 reviews
#
#                                     hotel_facilities  \
# 0  ['Free WiFi', 'Non-smoking rooms', 'Free WiFi'...
# 1  ['Free parking', 'Free WiFi', 'Non-smoking roo...
# 2  ['Outdoor swimming pool', 'Free parking', 'Fre...
# 3  ['Free WiFi', 'Free WiFi', 'Kitchen', 'Dishwas...
# 4  ['Parking', 'Free WiFi', 'Family rooms', 'Non-...
#
#                                    hotel_description  \
# 0  Situated in Collioure, 90 metres from Boramar ...
# 1  Set in Collioure and only 500 metres from Regu...
# 2  Situated in Collioure, T3 piscine clim wifi ga...
# 3  A recently renovated property, Lumières à Coll...
# 4  Located in Collioure, 200 metres from Port Ava...
#
#                                    url_booking_hotel  lat_hotel  lon_hotel
# 0  https://www.booking.com/hotel/fr/matisse-studi...  42.527032   3.084534
# 1  https://www.booking.com/hotel/fr/escale-de-col...  42.521823   3.093709
# 2  https://www.booking.com/hotel/fr/t3-piscine-cl...  42.526992   3.075032
# 3  https://www.booking.com/hotel/fr/lumieres-a-co...  42.527102   3.084495
# 4  https://www.booking.com/hotel/fr/les-suites-de...  42.524390   3.082726
#
# [5 rows x 26 columns]

# %%
import plotly.express as px

fig = px.scatter_mapbox(top_city_hotel_df, lat="lat_hotel", lon="lon_hotel", hover_name="hotel_name", hover_data=["hotel_address", "hotel_rating", "temp_day (°C)", "feels_like_day (°C)"],
                        color="city", zoom=6, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
